# %%
# !pwd
# Out:
# /Users/akito/Dev/Python_env/oit_develop_event_tools

# %%
import pandas as pd

# %%
test =pd.read_csv('syllabus_database.csv')

# %%
test.describe()
# Out:
#            コンピュータ入門  １年次   前期    牧野博之(マキノヒロシ)  1AAB01A0
# count           672  672  672             672       672
# unique          200    4    7              99       672
# top     コンピュータリテラシー  １年次   前期  水谷泰治(ミズタニヤスハル)  1BCB27A0
# freq             19  248  332              26         1

# %%
test[400:420]
# Out:
#            コンピュータ入門  １年次      前期                    牧野博之(マキノヒロシ)  1AAB01A0
# 400       プログラミング入門  １年次      前期                  布村泰浩(ヌノムラヤスヒロ)  1ECB10B0
# 401     コンピュータリテラシー  １年次      前期                  平岡一剛(ヒラオカカズタケ)  1ECB26B0
# 402  インターフェース・センサ回路  ２年次      前期                    荒木英夫(アラキヒデオ)  1ECL30A0
# 403        コンピュータ入門  １年次      前期                    樫原茂(カシハラシゲル)  1FAB01A0
# 404      情報通信ネットワーク  ２年次      前期                   島野顕継(シマノアキツグ)  1FAB02A0
# 405     テクニカルライティング  １年次      後期                    田邉信二(タナベシンジ)  1FAB05A0
# 406     テクニカルライティング  １年次      後期                    田邉信二(タナベシンジ)  1FAB05B0
# 407      計算機アーキテクチャ  ２年次      前期                  大島一能(オオシマカズヨシ)  1FAB11A0
# 408    ネットワークデザイン入門  １年次  前期（前半）  塚本　勝俊(ツカモト　カツトシ)酒澤茂之(サカザワシゲユキ)  1FAB24A0
# 409            Ｃ演習Ⅰ  １年次      後期                  水谷泰治(ミズタニヤスハル)  1FAN03A0
# 410  ネットワークデザイン基礎演習  ２年次      後期  酒澤　茂之(サカザワ　シゲユキ)大島一能(オオシマカズヨシ)  1FAN07A0
# ...

# %%
grades = test['１年次'].unique()

# %%
grades
# Out:
# array(['１年次', '２年次', '３年次', '４年次'], dtype=object)

# %%
periods = test['前期'].unique()

# %%
periods
# Out:
# array(['後期', '前期', '後期集中', '前期（前半）', '前期（後半）', '後期（後半）', '集中'],
#       dtype=object)

# %%
teachers = test['牧野博之(マキノヒロシ)'].unique()

# %%
teachers
# Out:
# array(['光田憲朗(ミツダケンロウ)', '荒木英夫(アラキヒデオ)', '牧野博之(マキノヒロシ)', '布村泰浩(ヌノムラヤスヒロ)',
#        '平岡一剛(ヒラオカカズタケ)', '小松信雄(コマツノブオ)', '尾崎敦夫(オザキアツオ)', '水谷泰治(ミズタニヤスハル)',
#        '小谷直樹(コタニナオキ)', '鎌倉良成(カマクラヨシナリ)', '中西知嘉子(ナカニシチカコ)',
#        '西口敏司(ニシグチサトシ)', '神田智子(コウダトモコ)', '奥野弘嗣(オクノヒロツグ)', '平嶋洋一(ヒラシマヨウイチ)',
#        '尾形尚子(オガタナオコ)', '真貝寿明(シンカイヒサアキ)', '齋藤洋介(サイトウヨウスケ)',
#        '地嵜頌子(チサキショウコ)', '樫原茂(カシハラシゲル)', '小西将人(コニシマサヒト)', '尾花将輝(オバナマサキ)',
#        '酒澤茂之(サカザワシゲユキ)', '井垣宏(イガキヒロシ)', '福島拓(フクシマタク)', '深海悟(フカミサトル)',
#        '安留誠吾(ヤストメセイゴ)', '平博順(タイラヒロトシ)', '神納貴生(ジンノウタカオ)', '中西通雄(ナカニシミチオ)',
#        '河合紀彦(カワイノリヒコ)', '藤井研一(フジイケンイチ)', '須永宏(スナガヒロシ)', '佐野睦夫(サノムツオ)',
#        '島野顕継(シマノアキツグ)', '山本雄平(ヤマモトユウヘイ)', '山田隆亮(ヤマダタカアキ)',
#        '山内雪路(ヤマウチユキジ)', '大島一能(オオシマカズヨシ)', '斉藤隆(サイトウタカシ)',
#        '鎌倉快之(カマクラヨシユキ)', '椎原正次(シイハラマサツグ)', '山内建二(ヤマウチケンジ)', '本田澄(ホンダキヨシ)',
#        '宮脇健三郎(ミヤワキケンザブロウ)', '内藤広志(ナイトウヒロシ)', '塚本勝俊(ツカモトカツトシ)',
#        '平山亮(ヒラヤママコト)', '橋本渉(ハシモトワタル)', '鈴木基之(スズキモトユキ)', '福澤寧子(フクザワヤスコ)',
# ...

# %%
lecture_codes = test['1AAB01A0'].unique()

# %%
lecture_codes
# Out:
# array(['1AAB05A0', '1AAB05B0', '1AAB07A0', '1AAB18A0', '1AAB18B0',
#        '1AAB23A0', '1AAD10B0', '1AAG10A0', '1AAG14A0', '1AAH03A0',
#        '1AAH07A0', '1AAH08A0', '1AAK01A0', '1AAL02A0', '1AAL07A0',
#        '1AAL27A0', '1AAN03A0', '1AAN07A0', '1AAN08A0', '1AAN09A0',
#        '1ABA01A0', '1ABA01B0', '1ABA01C0', '1ABA03A0', '1ABA03B0',
#        '1ABA03C0', '1ABA05A0', '1ABA08A0', '1ABB02A0', '1ABB04A0',
#        '1ABB13A0', '1ABB21A0', '1ABC04A0', '1ABC06A0', '1ABC07A0',
#        '1ABD09A0', '1ABD14A0', '1ABH06A0', '1ABL01A0', '1ABL03A0',
#        '1ABL04A0', '1ABL09A0', '1ABL11A0', '1ABL32A0', '1ABN04A0',
#        '1ABN05A0', '1ABN06A0', '1ACA04A0', '1ACA06A0', '1ACA07A0',
#        '1ACA07B0', '1ACA10A0', '1ACB03A0', '1ACB08A0', '1ACB10A0',
#        '1ACB10B0', '1ACB26A0', '1ACB26B0', '1ACC05A0', '1ACC08A0',
#        '1ACC08B0', '1ACD03A0', '1ACD05A0', '1ACD15A0', '1ACE02A0',
#        '1ACE02B0', '1ACE19A0', '1ACF04A0', '1ACG02A0', '1ACG11A0',
# ...

# %%
subjects = test['コンピュータ入門'].unique()

# %%
subjects
# Out:
# array(['テクニカルライティング', 'ディジタル回路', 'アセンブリ言語', '組み込みシステム基礎', '情報技術者論',
#        'Ｃ演習Ⅰ', 'コンピュータ科学基礎演習', 'コンピュータ科学専門演習', '情報ゼミナール', '計算機アーキテクチャ',
#        'オペレーティングシステム', '情報科学演習Ⅰ', '情報科学演習Ⅱ', '情報科学演習Ⅲ', '線形数学Ⅰ', '微積分学Ⅰ',
#        '情報数学', 'グラフ理論', '情報通信ネットワーク', 'オートマトンと形式言語', 'データ構造とアルゴリズムⅠ',
#        'ソフトウェア工学Ⅰ', 'プロセッサ設計', '情報セキュリティ', '集積回路工学', 'プログラミング言語論',
#        'ソフトウェア工学Ⅱ', 'ソフトウェア工学演習', 'データベースシステム', '情報セキュリティの基礎', 'Ｃ演習Ⅱ',
#        'Java演習', '微積分学Ⅱ', '周波数解析', '微分方程式', '数値計算演習', 'プログラミング基礎',
#        '情報処理基礎', 'プログラミング入門', 'コンピュータリテラシー', 'ディジタル回路応用', '集積回路設計',
#        'データ構造とアルゴリズムⅡ', 'システムプログラム', 'Unixプログラミング', 'コンピュータグラフィックスⅠ',
#        '画像処理', '信号処理', 'キャリアデザインⅠ', 'ロボット制御', 'ロボット工学基礎', 'ロボット工学演習',
#        'インターフェース・センサ回路', '知能制御工学基礎', '知能情報処理', '知能制御工学', '知能制御工学演習',
#        'コンピュータ入門', '情報システム基礎演習', '情報システム専門演習', '確率・統計', 'ネットワーク設計',
#        '情報システムの計画策定', 'システム工学', '情報システム応用演習', '線形数学Ⅱ', 'Ｕｎｉｘシステム入門',
#        '情報検索', '人工知能', '構造化文書処理', 'ヒューマンインタフェース', '通信理論',
# ...
